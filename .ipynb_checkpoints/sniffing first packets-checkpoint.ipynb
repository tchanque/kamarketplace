# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Paquet-interpretation" data-toc-modified-id="Paquet-interpretation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Paquet interpretation</a></span><ul class="toc-item"><li><span><a href="#Decompose-the-paquet" data-toc-modified-id="Decompose-the-paquet-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Decompose the paquet</a></span></li><li><span><a href="#Mapping-the-Ids" data-toc-modified-id="Mapping-the-Ids-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Mapping the Ids</a></span><ul class="toc-item"><li><span><a href="#Gotta-need-to-decompile-the-source-code-first" data-toc-modified-id="Gotta-need-to-decompile-the-source-code-first-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Gotta need to decompile the source code first</a></span></li><li><span><a href="#Then-extract-the-mapping-of-the-Ids" data-toc-modified-id="Then-extract-the-mapping-of-the-Ids-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Then extract the mapping of the Ids</a></span></li></ul></li></ul></li><li><span><a href="#Deserialize" data-toc-modified-id="Deserialize-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Deserialize</a></span></li></ul></div>

# %%
import pyshark
import nest_asyncio
nest_asyncio.apply()

# %%
capture = pyshark.LiveCapture(interface='en0', bpf_filter='tcp port 5555 and len > 66')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 capture = pyshark.LiveCapture(interface='en0', bpf_filter='tcp port 5555 and len > 66')
#
# File ~/.pyenv/versions/3.8.12/envs/kamarketplace/lib/python3.8/site-packages/pyshark/capture/live_capture.py:58, in LiveCapture.__init__(self, interface, bpf_filter, display_filter, only_summaries, decryption_key, encryption_type, output_file, decode_as, disable_protocol, tshark_path, override_prefs, capture_filter, monitor_mode, use_json, use_ek, include_raw, eventloop, custom_parameters, debug)
#      55 self.bpf_filter = bpf_filter
#      56 self.monitor_mode = monitor_mode
# ---> 58 all_interfaces = get_tshark_interfaces(tshark_path)
#      59 if interface is None:
#      60     self.interfaces = all_interfaces
#
# File ~/.pyenv/versions/3.8.12/envs/kamarketplace/lib/python3.8/site-packages/pyshark/tshark/tshark.py:114, in get_tshark_interfaces(tshark_path)
#     112 parameters = [get_process_path(tshark_path), "-D"]
#     113 with open(os.devnull, "w") as null:
# --> 114     tshark_interfaces = subprocess.check_output(parameters, stderr=null).decode("utf-8")
#     116 return [line.split(" ")[1] for line in tshark_interfaces.splitlines() if '\\\\.\\' not in line]
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/subprocess.py:415, in check_output(timeout, *popenargs, **kwargs)
#     412         empty = b''
#     413     kwargs['input'] = empty
# --> 415 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416            **kwargs).stdout
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/subprocess.py:495, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     493 with Popen(*popenargs, **kwargs) as process:
#     494     try:
# --> 495         stdout, stderr = process.communicate(input, timeout=timeout)
#     496     except TimeoutExpired as exc:
#     497         process.kill()
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/subprocess.py:1015, in Popen.communicate(self, input, timeout)
#    1013     self._stdin_write(input)
#    1014 elif self.stdout:
# -> 1015     stdout = self.stdout.read()
#    1016     self.stdout.close()
#    1017 elif self.stderr:
#
# KeyboardInterrupt:

# %%
capture.sniff(timeout=20)

# %%
print(capture)
# Out:
# <LiveCapture (27 packets)>

# %%
6999

# %%
\print("[DEBUG] {} paquets reçus".format( len(capture) ) )
for packet in capture:
            print(packet.tcp.payload)
# Out:
# [DEBUG] 23 paquets reçus
# 54:e1:bd:14:08:42:54:66:8d:80:34:80:00:12:1f:00:ee:01:01:00:06:5a:df:10:ef:01:b3:0b:43:ce:04:00:09:01:ff:c8:67:02:f4:76:00:03:4e:4e:4e:04:6a:00:00:05:fa:97:17:07:ff:ff:ff:08:0d:04:ee:09:4e:a1:fe:0a:00:00:00:00:01:8c:01:00:00:00:0f:50:69:78:65:6c:2d:4c:65:2d:52:65:74:6f:75:72:0d:e0:00:08:00:00:00:04:25:6f:ca:95:01:00:0b:41:2d:53:2d:54:2d:52:2d:4f:2d:53:26:0f:00:0d:04:ee:04:00:ff:ff:ff:13:29:8a:16:00:04:43:52:4f:43:00:10:43:72:6f:71:75:61:6e:74:20:63:72:6f:71:75:65:72:ce:03:00:00:00:00:03:00:4e:a1:fe:00:14:a5:45:00:00:1d:62:01:0a:1e:bb:de:00:00:00:42:54:66:8d:80:3c:00:00
# 8d:b1:0b:00:01:d2:81:d8:d1:99:0a:00:01:00
# 1f:31:0b:42:54:66:8d:80:34:80:00:00:08:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [7], line 2
#       1 print("[DEBUG] {} paquets reçus".format( len(capture) ) )
# ----> 2 for packet in capture:
#       3             print(packet.tcp.payload)
#
# File ~/.pyenv/versions/3.8.12/envs/kamarketplace/lib/python3.8/site-packages/pyshark/capture/capture.py:221, in Capture._packets_from_tshark_sync(self, packet_count, existing_process)
#     219 while True:
#     220     try:
# --> 221         packet, data = self.eventloop.run_until_complete(
#     222             parser.get_packets_from_stream(tshark_process.stdout, data,
#     223                                            got_first_packet=packets_captured > 0))
#     225     except EOFError:
#     226         self._log.debug("EOF reached (sync)")
#
# File ~/.pyenv/versions/3.8.12/envs/kamarketplace/lib/python3.8/site-packages/nest_asyncio.py:84, in _patch_loop.<locals>.run_until_complete(self, future)
#      82     f._log_destroy_pending = False
#      83 while not f.done():
# ---> 84     self._run_once()
#      85     if self._stopping:
#      86         break
#
# File ~/.pyenv/versions/3.8.12/envs/kamarketplace/lib/python3.8/site-packages/nest_asyncio.py:107, in _patch_loop.<locals>._run_once(self)
#     100     heappop(scheduled)
#     102 timeout = (
#     103     0 if ready or self._stopping
#     104     else min(max(
#     105         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     106     else None)
# --> 107 event_list = self._selector.select(timeout)
#     108 self._process_events(event_list)
#     110 end_time = self.time() + self._clock_resolution
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/selectors.py:558, in KqueueSelector.select(self, timeout)
#     556 ready = []
#     557 try:
# --> 558     kev_list = self._selector.control(None, max_ev, timeout)
#     559 except InterruptedError:
#     560     return ready
#
# KeyboardInterrupt:

# %%
len(capture)
# Out:
# 23

# %%
packet_test = capture[1]

# %%
packet_test.DATA.data
# Out:
# '87810316ee0852311000020125014100014253cfb300348000345c'

# %%
my_packet = packet_test.tcp.payload
my_packet
# Out:
# '87:81:03:16:ee:08:52:31:10:00:02:01:25:01:41:00:01:42:53:cf:b3:00:34:80:00:34:5c'

# %% [markdown]
# # Paquet interpretation

# %% [markdown]
# ## Decompose the paquet

# %%
class Packet:
    def __init__(self, packetPayLoad):
        self.payload = packetPayLoad
        self.header = self.get_header()
        self.id = self.get_id()
        self.size_of_size = self.get_size_of_size()
        self.size_packet = self.get_size_packet()
        self.size_message = self.get_size_message()
        
    def get_header(self):
        return ''.join(self.payload.split(':')[:2])
        
    def get_bin_header(self):
        scale = 16 #hexadecimal
        num_of_bits = 16
        header = self.header
        
        return bin(int(header, scale))[2:].zfill(num_of_bits)
        
    def get_id(self):
        if ~hasattr(self, "bin_header"):
            self.bin_header = self.get_bin_header()
        
        return int(self.bin_header[:14], 2)
    
    def get_size_of_size(self):
        if ~hasattr(self, "bin_header"):
            self.bin_header = self.get_bin_header()
        return int(self.bin_header[-2:], 2)
    
    def get_size_packet(self):
        return ''.join(self.payload.split(":")[2 : 2+self.size_of_size])
    
    def get_size_message(self):
        return int(self.size_packet, base=16)

# %%
my_packet = "54:e1:bd:14:08:42:54:66:8d:80:34:80:00:12:1f:00:ee:01:01:00:06:5a:df:10:ef:01:b3:0b:43:ce:04:00:09:01:ff:c8:67:02:f4:76:00:03:4e:4e:4e:04:6a:00:00:05:fa:97:17:07:ff:ff:ff:08:0d:04:ee:09:4e:a1:fe:0a:00:00:00:00:01:8c:01:00:00:00:0f:50:69:78:65:6c:2d:4c:65:2d:52:65:74:6f:75:72:0d:e0:00:08:00:00:00:04:25:6f:ca:95:01:00:0b:41:2d:53:2d:54:2d:52:2d:4f:2d:53:26:0f:00:0d:04:ee:04:00:ff:ff:ff:13:29:8a:16:00:04:43:52:4f:43:00:10:43:72:6f:71:75:61:6e:74:20:63:72:6f:71:75:65:72:ce:03:00:00:00:00:03:00:4e:a1:fe:00:14:a5:45:00:00:1d:62:01:0a:1e:bb:de:00:00:00:42:54:66:8d:80:3c:00:00:8d:b1:0b:00:01:d2:81:d8:d1:99:0a:00:01:00:1f:31:0b:42:54:66:8d:80:34:80:00:00:08:00"
# capture[1].tcp.payload
print(my_packet)
# Out:
# 54:e1:bd:14:08:42:54:66:8d:80:34:80:00:12:1f:00:ee:01:01:00:06:5a:df:10:ef:01:b3:0b:43:ce:04:00:09:01:ff:c8:67:02:f4:76:00:03:4e:4e:4e:04:6a:00:00:05:fa:97:17:07:ff:ff:ff:08:0d:04:ee:09:4e:a1:fe:0a:00:00:00:00:01:8c:01:00:00:00:0f:50:69:78:65:6c:2d:4c:65:2d:52:65:74:6f:75:72:0d:e0:00:08:00:00:00:04:25:6f:ca:95:01:00:0b:41:2d:53:2d:54:2d:52:2d:4f:2d:53:26:0f:00:0d:04:ee:04:00:ff:ff:ff:13:29:8a:16:00:04:43:52:4f:43:00:10:43:72:6f:71:75:61:6e:74:20:63:72:6f:71:75:65:72:ce:03:00:00:00:00:03:00:4e:a1:fe:00:14:a5:45:00:00:1d:62:01:0a:1e:bb:de:00:00:00:42:54:66:8d:80:3c:00:00:8d:b1:0b:00:01:d2:81:d8:d1:99:0a:00:01:00:1f:31:0b:42:54:66:8d:80:34:80:00:00:08:00

# %%
testing_a_packet_class = Packet(my_packet)

# %%
testing_a_packet_class.payload
# Out:
# '54:e1:bd:14:08:42:54:66:8d:80:34:80:00:12:1f:00:ee:01:01:00:06:5a:df:10:ef:01:b3:0b:43:ce:04:00:09:01:ff:c8:67:02:f4:76:00:03:4e:4e:4e:04:6a:00:00:05:fa:97:17:07:ff:ff:ff:08:0d:04:ee:09:4e:a1:fe:0a:00:00:00:00:01:8c:01:00:00:00:0f:50:69:78:65:6c:2d:4c:65:2d:52:65:74:6f:75:72:0d:e0:00:08:00:00:00:04:25:6f:ca:95:01:00:0b:41:2d:53:2d:54:2d:52:2d:4f:2d:53:26:0f:00:0d:04:ee:04:00:ff:ff:ff:13:29:8a:16:00:04:43:52:4f:43:00:10:43:72:6f:71:75:61:6e:74:20:63:72:6f:71:75:65:72:ce:03:00:00:00:00:03:00:4e:a1:fe:00:14:a5:45:00:00:1d:62:01:0a:1e:bb:de:00:00:00:42:54:66:8d:80:3c:00:00:8d:b1:0b:00:01:d2:81:d8:d1:99:0a:00:01:00:1f:31:0b:42:54:66:8d:80:34:80:00:00:08:00'

# %%
print("The header hexadecimal value is %s" %(testing_a_packet_class.header))
print("The packet ID is %s while the size of the size is %s" %(testing_a_packet_class.id,
                                                             testing_a_packet_class.size_of_size))
print("The message size in hexa is then %s which represents %s bytes after conversion" 
      %(testing_a_packet_class.size_packet, testing_a_packet_class.size_message))
# Out:
# The header hexadecimal value is 54e1
# The packet ID is 5432 while the size of the size is 1
# The message size in hexa is then bd which represents 189 bytes after conversion

# %% [markdown]
# ## Mapping the Ids

# %% [markdown]
# ### Gotta need to decompile the source code first

# %%
source_code_path = "/Applications/Ankama/Dofus/Dofus.app/Contents/Resources/DofusInvoker.swf"

# %% [markdown]
# USE JPEXS Free Flash Decompiler to decompile the source code

# %% [markdown]
# ### Then extract the mapping of the Ids

# %%
import os

def Ids(path='/Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages'):
    fichiers=[os.path.join(path, f) for f in os.listdir(path) if os.path.isfile(os.path.join(path, f)) and f != '.DS_Store' and f != 'Ids.py']
    dossiers=[os.path.join(path, f) for f in os.listdir(path) if os.path.isdir(os.path.join(path, f))]
    for f in fichiers:
        o=open(f)
        r=o.read()
        o.close()
        first_occurence=r.find('protocolId:uint =')
        if first_occurence != -1: # means the value is found
            id_location=int(first_occurence + 18) # look 18 characters after (length of 'protocolId:uint = ') to know when the protocolID's value is declared
            end_first_occurence=int(r.find(';', id_location))
            indice=r[id_location: end_first_occurence]
            nom=os.path.basename(f)[:-3]
            dictIds[indice]=nom
            
    for d in dossiers:
        Ids(d)

def createIds(path='/Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages'):
    ### crée le dictionnaire dictIds et le remplit
    global dictIds
    dictIds = dict()
    Ids(path)
    print('Terminé '+str(len(dictIds)))

import pickle

def dumpIds(path='./Ids'):
    ### crée le dictionnaire dictIds, le remplit et le sauvegarde
    createIds()
    f = open(path, 'wb')
    pickle.dump(dictIds, f)
    f.close()
    
def loadIds():
    ### charge le dictionnaire dictIds depuis le fichier
    f = open('./Ids', 'rb') #'/Users/louisabraham/Documents/Projet bot/Programme/Ids
    global dictIds
    dictIds = pickle.load(f)
    f.close()

# %%
def Ids(path='/Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages'):
    fichiers=[os.path.join(path, f) for f in os.listdir(path) if os.path.isfile(os.path.join(path, f)) and f != '.DS_Store' and f != 'Ids.py']
    dossiers=[os.path.join(path, f) for f in os.listdir(path) if os.path.isdir(os.path.join(path, f))]
    for f in fichiers:
        print(f)
        o=open(f)
        r=o.read()
        o.close()
        first_occurence=r.find('protocolId:uint =')
        if first_occurence != -1: # means the value is found
            id_location=int(first_occurence + 18) # look 18 characters after (length of 'protocolId:uint = ') to know when the protocolID's value is declared
            end_first_occurence=int(r.find(';', id_location))
            
            print(id_location, end_first_occurence)
            print(r[id_location: end_first_occurence])
            
            indice=r[id_location: end_first_occurence]
            nom=os.path.basename(f)[:-3]
            dictIds[indice]=nom
            
    for d in dossiers:
        Ids(d)

# %%
Ids()
# Out:
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/authorized/ConsoleCommandsListMessage.as
# 609 613
# 5071
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/authorized/AdminQuietCommandMessage.as
# 553 557
# 2805
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/authorized/AdminCommandMessage.as
# 602 606
# 5319
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/authorized/ConsoleMessage.as
# 597 601
# 4636
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/CredentialsAcknowledgementMessage.as
# 616 620
# 5801
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/IdentificationSuccessWithLoginTokenMessage.as
# 656 660
# 9913
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/HelloConnectMessage.as
# 602 606
# 1491
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/IdentificationAccountForceMessage.as
# 627 630
# 709
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/ServerSelectionMessage.as
# 605 609
# 6290
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/ServerStatusUpdateMessage.as
# 689 693
# 8161
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/IdentificationFailedForBadVersionMessage.as
# 640 644
# 5040
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/SelectedServerDataExtendedMessage.as
# 649 653
# 3597
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/IdentificationMessage.as
# 736 740
# 8494
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/IdentificationSuccessMessage.as
# 756 760
# 7076
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/ServersListMessage.as
# 682 686
# 2265
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/IdentificationFailedBannedMessage.as
# 570 572
# 46
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/SelectedServerRefusedMessage.as
# 611 615
# 5031
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/SelectedServerDataMessage.as
# 608 612
# 1970
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/IdentificationFailedMessage.as
# 610 614
# 8116
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/MigratedServerListMessage.as
# 608 612
# 6624
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/search/AcquaintanceSearchMessage.as
# 691 695
# 7040
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/search/AcquaintanceServerListMessage.as
# 619 623
# 5012
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/search/AcquaintanceSearchErrorMessage.as
# 620 624
# 5594
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/register/AccountLinkRequiredMessage.as
# 618 622
# 2364
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/register/NicknameRefusedMessage.as
# 614 618
# 1232
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/register/NicknameRegistrationMessage.as
# 619 623
# 8490
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/register/NicknameChoiceRequestMessage.as
# 620 624
# 1932
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/register/NicknameAcceptedMessage.as
# 615 619
# 3602
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/security/ClientKeyMessage.as
# 597 601
# 2298
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/security/CheckIntegrityMessage.as
# 602 606
# 9803
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/security/RawDataMessage.as
# 595 599
# 6253
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/security/CheckFileMessage.as
# 597 601
# 3391
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/security/CheckFileRequestMessage.as
# 604 608
# 6608
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiConsumeBufferRequestMessage.as
# 614 618
# 8060
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiBufferListRequestMessage.as
# 611 615
# 9893
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiCancelBidRequestMessage.as
# 610 614
# 3030
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiConfirmationRequestMessage.as
# 613 617
# 3865
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiTokenMessage.as
# 599 602
# 611
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiBuyValidationMessage.as
# 556 560
# 3570
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiSessionMessage.as
# 601 605
# 5999
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiBufferListMessage.as
# 679 682
# 597
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiApiKeyMessage.as
# 600 604
# 5592
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiApiKeyRequestMessage.as
# 607 611
# 9227
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiShopApiKeyRequestMessage.as
# 611 614
# 335
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiValidationMessage.as
# 604 608
# 7743
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiValidationRequestMessage.as
# 611 615
# 9241
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiConfirmationMessage.as
# 606 610
# 1582
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiAuthErrorMessage.as
# 603 606
# 543
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiTokenRequestMessage.as
# 606 610
# 5832
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiShopApiKeyMessage.as
# 604 608
# 1922
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/handshake/ProtocolRequired.as
# 598 601
# 950
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/server/basic/SystemMessageDisplayMessage.as
# 612 616
# 6917
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/PaginationRequestAbstractMessage.as
# 609 613
# 3502
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/PaginationAnswerAbstractMessage.as
# 608 612
# 9086
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/ui/ClientUIOpenedByObjectMessage.as
# 557 561
# 2353
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/ui/ClientUIOpenedMessage.as
# 601 605
# 8613
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarAddErrorMessage.as
# 612 616
# 5132
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarReplacedMessage.as
# 743 747
# 3012
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarRemoveErrorMessage.as
# 615 619
# 3243
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarSwapRequestMessage.as
# 615 618
# 856
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarContentMessage.as
# 742 746
# 1418
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarRemovedMessage.as
# 611 615
# 6762
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarAddRequestMessage.as
# 745 749
# 1534
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarRefreshMessage.as
# 742 746
# 3844
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarRemoveRequestMessage.as
# 617 621
# 3160
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarSwapErrorMessage.as
# 613 617
# 4366
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolSelectErrorMessage.as
# 673 677
# 6480
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolListMessage.as
# 725 729
# 5440
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolPartyRegisterRequestMessage.as
# 613 617
# 7229
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolPartyRefreshMessage.as
# 672 675
# 443
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolFightPreparationUpdateMessage.as
# 738 741
# 398
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolSelectRequestMessage.as
# 675 678
# 831
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolSelectedMessage.as
# 670 674
# 2669
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolPartyLostMessage.as
# 602 606
# 7552
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/GuildMemberSetWarnOnConnectionMessage.as
# 621 625
# 4648
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/WarnOnPermaDeathStateMessage.as
# 612 616
# 9933
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendWarnOnLevelGainStateMessage.as
# 617 621
# 1208
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/AcquaintancesGetListMessage.as
# 611 615
# 6188
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendStatusShareStateMessage.as
# 613 617
# 9213
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/IgnoredDeleteResultMessage.as
# 755 759
# 8239
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendWarnOnConnectionStateMessage.as
# 618 622
# 6424
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendSpouseJoinRequestMessage.as
# 614 618
# 7908
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/AcquaintanceAddedMessage.as
# 752 755
# 147
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/GuildMemberWarnOnConnectionStateMessage.as
# 623 626
# 201
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/IgnoredAddedMessage.as
# 743 747
# 8291
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendsListMessage.as
# 741 745
# 5246
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendAddFailureMessage.as
# 607 610
# 297
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/IgnoredListMessage.as
# 742 746
# 1630
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendDeleteResultMessage.as
# 685 689
# 4684
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendUpdateMessage.as
# 742 746
# 2802
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendAddRequestMessage.as
# 754 758
# 5110
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendAddedMessage.as
# 741 745
# 4797
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendsGetListMessage.as
# 605 609
# 5021
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/IgnoredAddRequestMessage.as
# 755 759
# 6590
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendDeleteRequestMessage.as
# 610 614
# 6447
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendSetWarnOnConnectionMessage.as
# 616 620
# 1867
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/IgnoredAddFailureMessage.as
# 608 611
# 919
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendSetStatusShareMessage.as
# 611 615
# 9827
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/SpouseGetInformationsMessage.as
# 612 616
# 4801
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendJoinRequestMessage.as
# 755 759
# 4873
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/ContactAddFailureMessage.as
# 608 612
# 8982
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendSetWarnOnLevelGainMessage.as
# 615 619
# 4417
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/AcquaintancesListMessage.as
# 752 756
# 5886
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/SpouseStatusMessage.as
# 603 607
# 1837
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/IgnoredDeleteRequestMessage.as
# 611 615
# 3716
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/SpouseInformationsMessage.as
# 754 757
# 610
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendSpouseFollowWithCompassRequestMessage.as
# 627 631
# 1305
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/IgnoredGetListMessage.as
# 605 609
# 9850
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/finishmoves/FinishMoveSetRequestMessage.as
# 616 619
# 687
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/finishmoves/FinishMoveListMessage.as
# 697 701
# 8317
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/finishmoves/FinishMoveListRequestMessage.as
# 617 621
# 3414
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementRewardSuccessMessage.as
# 620 624
# 8816
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementFinishedInformationMessage.as
# 673 676
# 988
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementListMessage.as
# 756 760
# 8153
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementDetailedListMessage.as
# 695 699
# 2346
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementRewardErrorMessage.as
# 618 622
# 3894
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementRewardRequestMessage.as
# 620 623
# 382
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementAlmostFinishedDetailedListMessage.as
# 709 713
# 4781
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementDetailsMessage.as
# 690 694
# 4523
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementDetailedListRequestMessage.as
# 626 630
# 2273
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/FriendGuildWarnOnAchievementCompleteStateMessage.as
# 637 641
# 8774
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementFinishedMessage.as
# 709 713
# 1669
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementDetailsRequestMessage.as
# 621 625
# 6908
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementAlmostFinishedDetailedListRequestMessage.as
# 640 644
# 3202
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/FriendGuildSetWarnOnAchievementCompleteMessage.as
# 635 639
# 8943
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextMoveElementMessage.as
# 701 705
# 4440
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameEntityDispositionMessage.as
# 713 717
# 7830
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapChangeOrientationRequestMessage.as
# 623 627
# 3816
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextRemoveMultipleElementsWithEventsMessage.as
# 602 605
# 806
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextQuitMessage.as
# 607 611
# 2114
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextCreateMessage.as
# 609 613
# 7413
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextRefreshEntityLookMessage.as
# 688 692
# 7415
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextMoveMultipleElementsMessage.as
# 710 714
# 8744
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapMovementRequestMessage.as
# 614 618
# 1134
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapChangeOrientationsMessage.as
# 694 698
# 3103
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextRemoveElementWithEventMessage.as
# 583 585
# 24
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextCreateErrorMessage.as
# 614 617
# 406
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextDestroyMessage.as
# 610 614
# 5265
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapMovementConfirmMessage.as
# 614 618
# 8699
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextCreateRequestMessage.as
# 616 620
# 3163
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameCautiousMapMovementMessage.as
# 564 568
# 5762
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextKickMessage.as
# 607 611
# 5632
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextRemoveElementMessage.as
# 616 620
# 4678
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/ShowCellRequestMessage.as
# 607 610
# 791
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapMovementCancelMessage.as
# 613 617
# 4121
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameCautiousMapMovementRequestMessage.as
# 578 582
# 4778
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/ShowCellMessage.as
# 600 604
# 3837
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextRemoveMultipleElementsMessage.as
# 625 629
# 9749
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameEntitiesDispositionMessage.as
# 715 719
# 3214
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameEntityDispositionErrorMessage.as
# 618 622
# 3357
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/ShowCellSpectatorMessage.as
# 551 555
# 1627
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapChangeOrientationMessage.as
# 693 697
# 5079
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapNoMovementMessage.as
# 609 613
# 9474
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameRefreshMonsterBoostsMessage.as
# 699 703
# 8618
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapMovementMessage.as
# 607 611
# 5260
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextReadyMessage.as
# 608 612
# 7651
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnReadyRequestMessage.as
# 623 627
# 4378
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementSwapPositionsCancelMessage.as
# 635 639
# 9103
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightHumanReadyStateMessage.as
# 622 625
# 962
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightNewRoundMessage.as
# 615 619
# 2322
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnListMessage.as
# 615 619
# 4479
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightJoinRequestMessage.as
# 618 622
# 4498
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPauseMessage.as
# 612 616
# 4240
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightSpectatePlayerRequestMessage.as
# 628 632
# 9412
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementSwapPositionsAcceptMessage.as
# 635 638
# 585
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightLeaveMessage.as
# 612 616
# 6629
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementPossiblePositionsMessage.as
# 633 637
# 2905
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementSwapPositionsErrorMessage.as
# 634 638
# 8913
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightOptionToggleMessage.as
# 619 623
# 6213
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementSwapPositionsRequestMessage.as
# 603 606
# 169
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightResumeMessage.as
# 998 1002
# 3789
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnFinishMessage.as
# 617 621
# 9910
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementSwapPositionsMessage.as
# 729 733
# 4869
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightRemoveTeamMemberMessage.as
# 623 627
# 2278
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightJoinMessage.as
# 680 684
# 3152
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnStartPlayingMessage.as
# 623 627
# 7936
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnEndMessage.as
# 614 618
# 2992
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightSynchronizeMessage.as
# 774 778
# 4244
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/SlaveSwitchContextMessage.as
# 934 938
# 2957
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightOptionStateUpdateMessage.as
# 624 628
# 5620
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnReadyMessage.as
# 616 620
# 1445
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightStartMessage.as
# 674 678
# 3234
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightSpectateMessage.as
# 960 964
# 4857
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnResumeMessage.as
# 569 572
# 606
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnStartMessage.as
# 616 620
# 6247
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightReadyMessage.as
# 612 616
# 2693
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightResumeWithSlavesMessage.as
# 1097 1101
# 2953
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/RefreshCharacterStatsMessage.as
# 710 714
# 1963
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightSpectatorJoinMessage.as
# 657 661
# 9884
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightStartingMessage.as
# 615 619
# 8108
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightEndMessage.as
# 859 863
# 9205
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementSwapPositionsOfferMessage.as
# 634 638
# 3078
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightNewWaveMessage.as
# 614 618
# 5865
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementSwapPositionsCancelledMessage.as
# 638 642
# 7028
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/SlaveNoLongerControledMessage.as
# 620 624
# 2828
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementPositionRequestMessage.as
# 631 635
# 8207
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightUpdateTeamMessage.as
# 705 709
# 5389
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/character/GameFightShowFighterMessage.as
# 784 788
# 1594
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/character/GameFightShowFighterRandomStaticPoseMessage.as
# 693 697
# 2123
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/character/GameFightRefreshFighterMessage.as
# 781 785
# 7180
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/arena/ArenaFighterIdleMessage.as
# 620 624
# 7833
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/arena/ArenaFighterLeaveMessage.as
# 717 721
# 8223
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/challenge/ChallengeResultMessage.as
# 623 627
# 4365
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/challenge/ChallengeTargetsListRequestMessage.as
# 635 639
# 6565
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/challenge/ChallengeTargetUpdateMessage.as
# 629 633
# 2531
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/challenge/ChallengeTargetsListMessage.as
# 628 632
# 2560
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/challenge/ChallengeInfoMessage.as
# 621 625
# 6123
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/breach/BreachGameFightEndMessage.as
# 846 850
# 9683
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/notification/NotificationResetMessage.as
# 622 626
# 4030
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/notification/NotificationByServerMessage.as
# 625 628
# 524
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/notification/NotificationListMessage.as
# 621 625
# 8907
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/notification/NotificationUpdateFlagMessage.as
# 627 631
# 9572
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/dungeon/DungeonKeyRingMessage.as
# 614 618
# 9531
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/dungeon/DungeonKeyRingUpdateMessage.as
# 620 624
# 5603
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountReleaseRequestMessage.as
# 617 621
# 6363
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountXpRatioMessage.as
# 610 614
# 1784
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountDataErrorMessage.as
# 612 615
# 191
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountFeedRequestMessage.as
# 614 618
# 1322
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountRenameRequestMessage.as
# 616 620
# 3920
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/PaddockBuyRequestMessage.as
# 615 619
# 2281
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountSterilizeRequestMessage.as
# 619 623
# 9407
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/GameDataPaddockObjectAddMessage.as
# 694 698
# 4990
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/GameDataPaddockObjectListAddMessage.as
# 698 702
# 6266
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountUnSetMessage.as
# 608 612
# 3691
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/PaddockBuyResultMessage.as
# 614 618
# 6859
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountHarnessDissociateRequestMessage.as
# 627 631
# 8879
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/PaddockMoveItemRequestMessage.as
# 620 624
# 9217
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountSterilizedMessage.as
# 613 617
# 6359
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountDataMessage.as
# 681 685
# 4654
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountHarnessColorsUpdateRequestMessage.as
# 629 633
# 2907
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountInformationRequestMessage.as
# 621 625
# 5819
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountSetXpRatioRequestMessage.as
# 620 624
# 3183
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountEmoteIconUsedOkMessage.as
# 618 622
# 2821
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountReleasedMessage.as
# 611 615
# 5899
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/GameDataPaddockObjectRemoveMessage.as
# 625 629
# 9249
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/PaddockSellRequestMessage.as
# 616 620
# 2577
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountEquipedErrorMessage.as
# 615 618
# 413
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountInformationInPaddockRequestMessage.as
# 630 634
# 8566
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/PaddockRemoveItemRequestMessage.as
# 622 626
# 1885
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountRenamedMessage.as
# 610 614
# 2109
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountRidingMessage.as
# 678 682
# 3146
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountToggleRidingRequestMessage.as
# 622 626
# 2686
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountSetMessage.as
# 680 684
# 1833
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/display/DisplayNumericalValuePaddockMessage.as
# 628 632
# 7152
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapFightCountMessage.as
# 614 618
# 5221
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/TeleportOnSameMapMessage.as
# 618 622
# 8301
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/SubareaRewardRateMessage.as
# 618 622
# 7872
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/CurrentMapMessage.as
# 611 615
# 8021
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapComplementaryInformationsDataInHavenBagMessage.as
# 1291 1295
# 9166
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/GameRolePlayShowActorMessage.as
# 782 786
# 5432
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapObstacleUpdateMessage.as
# 694 698
# 3115
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/StopToListenRunningFightRequestMessage.as
# 632 636
# 7218
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/CurrentMapInstanceMessage.as
# 563 567
# 9701
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/DiceRollRequestMessage.as
# 616 620
# 2939
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapComplementaryInformationsWithCoordsMessage.as
# 1196 1200
# 4600
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapRunningFightDetailsExtendedMessage.as
# 777 781
# 3023
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapInformationsRequestMessage.as
# 623 627
# 6532
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/GameRolePlayShowActorWithEventMessage.as
# 685 689
# 9756
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapFightStartPositionsUpdateMessage.as
# 718 722
# 2289
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/GameRolePlayShowMultipleActorsMessage.as
# 791 795
# 6327
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapComplementaryInformationsDataInHouseMessage.as
# 1279 1283
# 8788
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapRunningFightListMessage.as
# 712 716
# 1693
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapRunningFightDetailsRequestMessage.as
# 630 634
# 5911
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/AnomalySubareaInformationRequestMessage.as
# 633 637
# 5479
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/ErrorMapNotFoundMessage.as
# 617 621
# 6569
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapRunningFightDetailsMessage.as
# 784 788
# 4377
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/AnomalySubareaInformationResponseMessage.as
# 729 733
# 6858
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/ChangeMapMessage.as
# 610 614
# 4712
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapComplementaryInformationsDataMessage.as
# 1285 1289
# 6062
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapRunningFightListRequestMessage.as
# 627 631
# 6402
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/anomaly/MapComplementaryInformationsAnomalyMessage.as
# 1313 1317
# 9668
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/anomaly/AnomalyOpenedMessage.as
# 622 626
# 6804
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/anomaly/AnomalyStateMessage.as
# 621 625
# 7886
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/fight/GameRolePlayAggressionMessage.as
# 629 633
# 3917
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/fight/GameRolePlayMonsterAngryAtPlayerMessage.as
# 639 642
# 470
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/fight/GameRolePlayPlayerFightFriendlyAnsweredMessage.as
# 646 650
# 1332
# ...
# 637 641
# 6438
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/CreateGuildRankRequestMessage.as
# 612 616
# 6742
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildGetChestTabContributionsRequestMessage.as
# 626 630
# 3036
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildInformationsGeneralMessage.as
# 614 618
# 5204
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildChestTabContributionsMessage.as
# 687 691
# 2687
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildKickRequestMessage.as
# 606 610
# 5916
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildPaddockBoughtMessage.as
# 695 699
# 5010
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildMotdSetErrorMessage.as
# 651 655
# 1589
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildCreationValidMessage.as
# 678 682
# 6479
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildMemberOnlineStatusMessage.as
# 613 617
# 5955
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildSelectChestTabRequestMessage.as
# 616 620
# 8333
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildInvitationSearchMessage.as
# 758 762
# 6288
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildModificationNameValidMessage.as
# 616 619
# 929
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildHouseRemoveMessage.as
# 606 610
# 4715
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildUpdateChestTabRequestMessage.as
# 707 711
# 8449
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildBulletinSetRequestMessage.as
# 661 665
# 1184
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildInformationsMemberUpdateMessage.as
# 689 693
# 8214
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildRanksMessage.as
# 679 683
# 2740
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildInAllianceFactsMessage.as
# 842 846
# 8611
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildSpellUpgradeRequestMessage.as
# 614 618
# 9315
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/StopListenGuildChestStructureMessage.as
# 619 623
# 1494
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildInvitationStateRecruterMessage.as
# 618 622
# 9160
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildInvitationMessage.as
# 605 609
# 2538
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildMemberLeavingMessage.as
# 608 612
# 7087
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildMotdSetRequestMessage.as
# 657 661
# 6060
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildCreationStartedMessage.as
# 610 614
# 9587
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildGetInformationsMessage.as
# 610 614
# 4881
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildMotdMessage.as
# 627 631
# 8900
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildChestTabContributionMessage.as
# 615 619
# 7980
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildModificationEmblemValidMessage.as
# 688 692
# 6730
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildVersatileInfoListMessage.as
# 759 763
# 2816
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildLevelUpMessage.as
# 602 606
# 4968
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildLeftMessage.as
# 599 603
# 8009
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildFactsErrorMessage.as
# 605 609
# 1805
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildModificationValidMessage.as
# 682 686
# 4016
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildInvitationAnswerMessage.as
# 611 615
# 1590
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/logbook/GuildLogbookInformationMessage.as
# 782 786
# 4346
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/logbook/GuildLogbookInformationRequestMessage.as
# 628 632
# 5393
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/recruitment/RecruitmentInformationMessage.as
# 722 726
# 5770
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/recruitment/GuildRecruitmentInvalidateMessage.as
# 628 632
# 4402
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/recruitment/UpdateRecruitmentInformationMessage.as
# 728 732
# 2295
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorListMessage.as
# 749 753
# 3385
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorErrorMessage.as
# 611 615
# 5423
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GuildFightPlayersEnemiesListMessage.as
# 721 724
# 494
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GuildFightPlayersHelpersJoinMessage.as
# 721 725
# 9864
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorMovementRemoveMessage.as
# 620 623
# 557
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorMovementMessage.as
# 706 710
# 1685
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GuildFightJoinRequestMessage.as
# 615 619
# 6440
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TopTaxCollectorListMessage.as
# 658 662
# 1294
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GuildFightPlayersHelpersLeaveMessage.as
# 623 627
# 7948
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GameRolePlayTaxCollectorFightRequestMessage.as
# 630 634
# 4237
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorMovementAddMessage.as
# 765 769
# 6144
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorAttackedResultMessage.as
# 804 808
# 5179
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorStateUpdateMessage.as
# 617 621
# 9802
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GuildFightTakePlaceRequestMessage.as
# 575 578
# 617
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GuildFightPlayersEnemyRemoveMessage.as
# 622 626
# 8467
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorAttackedMessage.as
# 706 710
# 5024
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GuildFightLeaveRequestMessage.as
# 616 620
# 7648
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorMovementsOfflineMessage.as
# 705 709
# 3305
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/AbstractTaxCollectorListMessage.as
# 766 770
# 5765
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/chest/RemoveListenerOnSynchronizedStorageMessage.as
# 631 635
# 5289
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/chest/ListenersOfSynchronizedStorageMessage.as
# 626 630
# 9734
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/chest/AddListenerOnSynchronizedStorageMessage.as
# 628 632
# 9135
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildDeleteApplicationRequestMessage.as
# 631 635
# 4677
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildPlayerApplicationAbstractMessage.as
# 632 636
# 9960
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildGetPlayerApplicationMessage.as
# 627 631
# 9033
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildListApplicationAnswerMessage.as
# 771 775
# 6506
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildApplicationAnswerMessage.as
# 624 628
# 3448
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildListApplicationModifiedMessage.as
# 728 732
# 2323
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildPlayerNoApplicationInformationMessage.as
# 601 605
# 7912
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildUpdateNoteMessage.as
# 617 620
# 486
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildSubmitApplicationMessage.as
# 624 628
# 4117
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildPlayerApplicationInformationMessage.as
# 784 788
# 6006
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildApplicationIsAnsweredMessage.as
# 715 719
# 3628
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildListApplicationRequestMessage.as
# 676 680
# 3750
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildUpdateApplicationMessage.as
# 624 628
# 1194
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildApplicationListenMessage.as
# 624 627
# 596
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildApplicationReceivedMessage.as
# 626 630
# 2640
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildApplicationDeletedMessage.as
# 625 628
# 930
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/subscription/AccountInformationsUpdateMessage.as
# 617 621
# 6161
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/common/NetworkDataContainerMessage.as
# 709 710
# 2
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/common/basic/BasicStatWithDataMessage.as
# 687 691
# 2395
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/common/basic/BasicPongMessage.as
# 601 604
# 693
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/common/basic/BasicStatMessage.as
# 601 605
# 8831
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/common/basic/BasicPingMessage.as
# 601 604
# 107
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/secure/TrustStatusMessage.as
# 666 669
# 321
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/queues/QueueStatusMessage.as
# 597 601
# 3862
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/queues/LoginQueueStatusMessage.as
# 602 606
# 3868
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/wtf/ClientYouAreDrunkMessage.as
# 624 628
# 9688
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/debug/DebugClearHighlightCellsMessage.as
# 609 613
# 4162
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/debug/DebugInClientMessage.as
# 598 602
# 5683
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/debug/DumpedEntityStatsMessage.as
# 704 708
# 9228
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/debug/DebugHighlightCellsMessage.as
# 604 608
# 8113

# %%
dumpIds()
# Out:
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/authorized/ConsoleCommandsListMessage.as
# 609 613
# 5071
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/authorized/AdminQuietCommandMessage.as
# 553 557
# 2805
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/authorized/AdminCommandMessage.as
# 602 606
# 5319
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/authorized/ConsoleMessage.as
# 597 601
# 4636
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/CredentialsAcknowledgementMessage.as
# 616 620
# 5801
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/IdentificationSuccessWithLoginTokenMessage.as
# 656 660
# 9913
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/HelloConnectMessage.as
# 602 606
# 1491
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/IdentificationAccountForceMessage.as
# 627 630
# 709
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/ServerSelectionMessage.as
# 605 609
# 6290
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/ServerStatusUpdateMessage.as
# 689 693
# 8161
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/IdentificationFailedForBadVersionMessage.as
# 640 644
# 5040
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/SelectedServerDataExtendedMessage.as
# 649 653
# 3597
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/IdentificationMessage.as
# 736 740
# 8494
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/IdentificationSuccessMessage.as
# 756 760
# 7076
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/ServersListMessage.as
# 682 686
# 2265
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/IdentificationFailedBannedMessage.as
# 570 572
# 46
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/SelectedServerRefusedMessage.as
# 611 615
# 5031
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/SelectedServerDataMessage.as
# 608 612
# 1970
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/IdentificationFailedMessage.as
# 610 614
# 8116
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/MigratedServerListMessage.as
# 608 612
# 6624
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/search/AcquaintanceSearchMessage.as
# 691 695
# 7040
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/search/AcquaintanceServerListMessage.as
# 619 623
# 5012
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/search/AcquaintanceSearchErrorMessage.as
# 620 624
# 5594
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/register/AccountLinkRequiredMessage.as
# 618 622
# 2364
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/register/NicknameRefusedMessage.as
# 614 618
# 1232
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/register/NicknameRegistrationMessage.as
# 619 623
# 8490
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/register/NicknameChoiceRequestMessage.as
# 620 624
# 1932
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/connection/register/NicknameAcceptedMessage.as
# 615 619
# 3602
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/security/ClientKeyMessage.as
# 597 601
# 2298
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/security/CheckIntegrityMessage.as
# 602 606
# 9803
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/security/RawDataMessage.as
# 595 599
# 6253
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/security/CheckFileMessage.as
# 597 601
# 3391
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/security/CheckFileRequestMessage.as
# 604 608
# 6608
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiConsumeBufferRequestMessage.as
# 614 618
# 8060
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiBufferListRequestMessage.as
# 611 615
# 9893
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiCancelBidRequestMessage.as
# 610 614
# 3030
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiConfirmationRequestMessage.as
# 613 617
# 3865
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiTokenMessage.as
# 599 602
# 611
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiBuyValidationMessage.as
# 556 560
# 3570
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiSessionMessage.as
# 601 605
# 5999
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiBufferListMessage.as
# 679 682
# 597
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiApiKeyMessage.as
# 600 604
# 5592
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiApiKeyRequestMessage.as
# 607 611
# 9227
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiShopApiKeyRequestMessage.as
# 611 614
# 335
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiValidationMessage.as
# 604 608
# 7743
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiValidationRequestMessage.as
# 611 615
# 9241
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiConfirmationMessage.as
# 606 610
# 1582
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiAuthErrorMessage.as
# 603 606
# 543
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiTokenRequestMessage.as
# 606 610
# 5832
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/web/haapi/HaapiShopApiKeyMessage.as
# 604 608
# 1922
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/handshake/ProtocolRequired.as
# 598 601
# 950
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/server/basic/SystemMessageDisplayMessage.as
# 612 616
# 6917
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/PaginationRequestAbstractMessage.as
# 609 613
# 3502
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/PaginationAnswerAbstractMessage.as
# 608 612
# 9086
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/ui/ClientUIOpenedByObjectMessage.as
# 557 561
# 2353
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/ui/ClientUIOpenedMessage.as
# 601 605
# 8613
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarAddErrorMessage.as
# 612 616
# 5132
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarReplacedMessage.as
# 743 747
# 3012
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarRemoveErrorMessage.as
# 615 619
# 3243
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarSwapRequestMessage.as
# 615 618
# 856
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarContentMessage.as
# 742 746
# 1418
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarRemovedMessage.as
# 611 615
# 6762
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarAddRequestMessage.as
# 745 749
# 1534
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarRefreshMessage.as
# 742 746
# 3844
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarRemoveRequestMessage.as
# 617 621
# 3160
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/shortcut/ShortcutBarSwapErrorMessage.as
# 613 617
# 4366
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolSelectErrorMessage.as
# 673 677
# 6480
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolListMessage.as
# 725 729
# 5440
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolPartyRegisterRequestMessage.as
# 613 617
# 7229
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolPartyRefreshMessage.as
# 672 675
# 443
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolFightPreparationUpdateMessage.as
# 738 741
# 398
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolSelectRequestMessage.as
# 675 678
# 831
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolSelectedMessage.as
# 670 674
# 2669
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/idol/IdolPartyLostMessage.as
# 602 606
# 7552
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/GuildMemberSetWarnOnConnectionMessage.as
# 621 625
# 4648
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/WarnOnPermaDeathStateMessage.as
# 612 616
# 9933
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendWarnOnLevelGainStateMessage.as
# 617 621
# 1208
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/AcquaintancesGetListMessage.as
# 611 615
# 6188
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendStatusShareStateMessage.as
# 613 617
# 9213
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/IgnoredDeleteResultMessage.as
# 755 759
# 8239
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendWarnOnConnectionStateMessage.as
# 618 622
# 6424
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendSpouseJoinRequestMessage.as
# 614 618
# 7908
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/AcquaintanceAddedMessage.as
# 752 755
# 147
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/GuildMemberWarnOnConnectionStateMessage.as
# 623 626
# 201
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/IgnoredAddedMessage.as
# 743 747
# 8291
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendsListMessage.as
# 741 745
# 5246
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendAddFailureMessage.as
# 607 610
# 297
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/IgnoredListMessage.as
# 742 746
# 1630
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendDeleteResultMessage.as
# 685 689
# 4684
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendUpdateMessage.as
# 742 746
# 2802
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendAddRequestMessage.as
# 754 758
# 5110
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendAddedMessage.as
# 741 745
# 4797
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendsGetListMessage.as
# 605 609
# 5021
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/IgnoredAddRequestMessage.as
# 755 759
# 6590
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendDeleteRequestMessage.as
# 610 614
# 6447
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendSetWarnOnConnectionMessage.as
# 616 620
# 1867
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/IgnoredAddFailureMessage.as
# 608 611
# 919
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendSetStatusShareMessage.as
# 611 615
# 9827
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/SpouseGetInformationsMessage.as
# 612 616
# 4801
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendJoinRequestMessage.as
# 755 759
# 4873
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/ContactAddFailureMessage.as
# 608 612
# 8982
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendSetWarnOnLevelGainMessage.as
# 615 619
# 4417
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/AcquaintancesListMessage.as
# 752 756
# 5886
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/SpouseStatusMessage.as
# 603 607
# 1837
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/IgnoredDeleteRequestMessage.as
# 611 615
# 3716
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/SpouseInformationsMessage.as
# 754 757
# 610
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/FriendSpouseFollowWithCompassRequestMessage.as
# 627 631
# 1305
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/friend/IgnoredGetListMessage.as
# 605 609
# 9850
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/finishmoves/FinishMoveSetRequestMessage.as
# 616 619
# 687
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/finishmoves/FinishMoveListMessage.as
# 697 701
# 8317
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/finishmoves/FinishMoveListRequestMessage.as
# 617 621
# 3414
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementRewardSuccessMessage.as
# 620 624
# 8816
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementFinishedInformationMessage.as
# 673 676
# 988
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementListMessage.as
# 756 760
# 8153
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementDetailedListMessage.as
# 695 699
# 2346
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementRewardErrorMessage.as
# 618 622
# 3894
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementRewardRequestMessage.as
# 620 623
# 382
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementAlmostFinishedDetailedListMessage.as
# 709 713
# 4781
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementDetailsMessage.as
# 690 694
# 4523
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementDetailedListRequestMessage.as
# 626 630
# 2273
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/FriendGuildWarnOnAchievementCompleteStateMessage.as
# 637 641
# 8774
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementFinishedMessage.as
# 709 713
# 1669
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementDetailsRequestMessage.as
# 621 625
# 6908
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/AchievementAlmostFinishedDetailedListRequestMessage.as
# 640 644
# 3202
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/achievement/FriendGuildSetWarnOnAchievementCompleteMessage.as
# 635 639
# 8943
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextMoveElementMessage.as
# 701 705
# 4440
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameEntityDispositionMessage.as
# 713 717
# 7830
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapChangeOrientationRequestMessage.as
# 623 627
# 3816
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextRemoveMultipleElementsWithEventsMessage.as
# 602 605
# 806
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextQuitMessage.as
# 607 611
# 2114
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextCreateMessage.as
# 609 613
# 7413
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextRefreshEntityLookMessage.as
# 688 692
# 7415
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextMoveMultipleElementsMessage.as
# 710 714
# 8744
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapMovementRequestMessage.as
# 614 618
# 1134
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapChangeOrientationsMessage.as
# 694 698
# 3103
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextRemoveElementWithEventMessage.as
# 583 585
# 24
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextCreateErrorMessage.as
# 614 617
# 406
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextDestroyMessage.as
# 610 614
# 5265
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapMovementConfirmMessage.as
# 614 618
# 8699
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextCreateRequestMessage.as
# 616 620
# 3163
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameCautiousMapMovementMessage.as
# 564 568
# 5762
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextKickMessage.as
# 607 611
# 5632
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextRemoveElementMessage.as
# 616 620
# 4678
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/ShowCellRequestMessage.as
# 607 610
# 791
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapMovementCancelMessage.as
# 613 617
# 4121
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameCautiousMapMovementRequestMessage.as
# 578 582
# 4778
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/ShowCellMessage.as
# 600 604
# 3837
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextRemoveMultipleElementsMessage.as
# 625 629
# 9749
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameEntitiesDispositionMessage.as
# 715 719
# 3214
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameEntityDispositionErrorMessage.as
# 618 622
# 3357
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/ShowCellSpectatorMessage.as
# 551 555
# 1627
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapChangeOrientationMessage.as
# 693 697
# 5079
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapNoMovementMessage.as
# 609 613
# 9474
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameRefreshMonsterBoostsMessage.as
# 699 703
# 8618
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameMapMovementMessage.as
# 607 611
# 5260
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/GameContextReadyMessage.as
# 608 612
# 7651
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnReadyRequestMessage.as
# 623 627
# 4378
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementSwapPositionsCancelMessage.as
# 635 639
# 9103
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightHumanReadyStateMessage.as
# 622 625
# 962
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightNewRoundMessage.as
# 615 619
# 2322
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnListMessage.as
# 615 619
# 4479
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightJoinRequestMessage.as
# 618 622
# 4498
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPauseMessage.as
# 612 616
# 4240
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightSpectatePlayerRequestMessage.as
# 628 632
# 9412
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementSwapPositionsAcceptMessage.as
# 635 638
# 585
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightLeaveMessage.as
# 612 616
# 6629
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementPossiblePositionsMessage.as
# 633 637
# 2905
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementSwapPositionsErrorMessage.as
# 634 638
# 8913
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightOptionToggleMessage.as
# 619 623
# 6213
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementSwapPositionsRequestMessage.as
# 603 606
# 169
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightResumeMessage.as
# 998 1002
# 3789
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnFinishMessage.as
# 617 621
# 9910
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementSwapPositionsMessage.as
# 729 733
# 4869
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightRemoveTeamMemberMessage.as
# 623 627
# 2278
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightJoinMessage.as
# 680 684
# 3152
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnStartPlayingMessage.as
# 623 627
# 7936
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnEndMessage.as
# 614 618
# 2992
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightSynchronizeMessage.as
# 774 778
# 4244
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/SlaveSwitchContextMessage.as
# 934 938
# 2957
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightOptionStateUpdateMessage.as
# 624 628
# 5620
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnReadyMessage.as
# 616 620
# 1445
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightStartMessage.as
# 674 678
# 3234
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightSpectateMessage.as
# 960 964
# 4857
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnResumeMessage.as
# 569 572
# 606
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightTurnStartMessage.as
# 616 620
# 6247
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightReadyMessage.as
# 612 616
# 2693
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightResumeWithSlavesMessage.as
# 1097 1101
# 2953
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/RefreshCharacterStatsMessage.as
# 710 714
# 1963
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightSpectatorJoinMessage.as
# 657 661
# 9884
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightStartingMessage.as
# 615 619
# 8108
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightEndMessage.as
# 859 863
# 9205
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementSwapPositionsOfferMessage.as
# 634 638
# 3078
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightNewWaveMessage.as
# 614 618
# 5865
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementSwapPositionsCancelledMessage.as
# 638 642
# 7028
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/SlaveNoLongerControledMessage.as
# 620 624
# 2828
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightPlacementPositionRequestMessage.as
# 631 635
# 8207
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/GameFightUpdateTeamMessage.as
# 705 709
# 5389
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/character/GameFightShowFighterMessage.as
# 784 788
# 1594
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/character/GameFightShowFighterRandomStaticPoseMessage.as
# 693 697
# 2123
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/character/GameFightRefreshFighterMessage.as
# 781 785
# 7180
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/arena/ArenaFighterIdleMessage.as
# 620 624
# 7833
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/arena/ArenaFighterLeaveMessage.as
# 717 721
# 8223
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/challenge/ChallengeResultMessage.as
# 623 627
# 4365
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/challenge/ChallengeTargetsListRequestMessage.as
# 635 639
# 6565
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/challenge/ChallengeTargetUpdateMessage.as
# 629 633
# 2531
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/challenge/ChallengeTargetsListMessage.as
# 628 632
# 2560
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/challenge/ChallengeInfoMessage.as
# 621 625
# 6123
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/fight/breach/BreachGameFightEndMessage.as
# 846 850
# 9683
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/notification/NotificationResetMessage.as
# 622 626
# 4030
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/notification/NotificationByServerMessage.as
# 625 628
# 524
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/notification/NotificationListMessage.as
# 621 625
# 8907
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/notification/NotificationUpdateFlagMessage.as
# 627 631
# 9572
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/dungeon/DungeonKeyRingMessage.as
# 614 618
# 9531
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/dungeon/DungeonKeyRingUpdateMessage.as
# 620 624
# 5603
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountReleaseRequestMessage.as
# 617 621
# 6363
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountXpRatioMessage.as
# 610 614
# 1784
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountDataErrorMessage.as
# 612 615
# 191
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountFeedRequestMessage.as
# 614 618
# 1322
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountRenameRequestMessage.as
# 616 620
# 3920
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/PaddockBuyRequestMessage.as
# 615 619
# 2281
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountSterilizeRequestMessage.as
# 619 623
# 9407
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/GameDataPaddockObjectAddMessage.as
# 694 698
# 4990
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/GameDataPaddockObjectListAddMessage.as
# 698 702
# 6266
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountUnSetMessage.as
# 608 612
# 3691
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/PaddockBuyResultMessage.as
# 614 618
# 6859
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountHarnessDissociateRequestMessage.as
# 627 631
# 8879
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/PaddockMoveItemRequestMessage.as
# 620 624
# 9217
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountSterilizedMessage.as
# 613 617
# 6359
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountDataMessage.as
# 681 685
# 4654
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountHarnessColorsUpdateRequestMessage.as
# 629 633
# 2907
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountInformationRequestMessage.as
# 621 625
# 5819
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountSetXpRatioRequestMessage.as
# 620 624
# 3183
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountEmoteIconUsedOkMessage.as
# 618 622
# 2821
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountReleasedMessage.as
# 611 615
# 5899
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/GameDataPaddockObjectRemoveMessage.as
# 625 629
# 9249
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/PaddockSellRequestMessage.as
# 616 620
# 2577
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountEquipedErrorMessage.as
# 615 618
# 413
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountInformationInPaddockRequestMessage.as
# 630 634
# 8566
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/PaddockRemoveItemRequestMessage.as
# 622 626
# 1885
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountRenamedMessage.as
# 610 614
# 2109
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountRidingMessage.as
# 678 682
# 3146
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountToggleRidingRequestMessage.as
# 622 626
# 2686
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/mount/MountSetMessage.as
# 680 684
# 1833
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/display/DisplayNumericalValuePaddockMessage.as
# 628 632
# 7152
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapFightCountMessage.as
# 614 618
# 5221
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/TeleportOnSameMapMessage.as
# 618 622
# 8301
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/SubareaRewardRateMessage.as
# 618 622
# 7872
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/CurrentMapMessage.as
# 611 615
# 8021
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapComplementaryInformationsDataInHavenBagMessage.as
# 1291 1295
# 9166
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/GameRolePlayShowActorMessage.as
# 782 786
# 5432
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapObstacleUpdateMessage.as
# 694 698
# 3115
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/StopToListenRunningFightRequestMessage.as
# 632 636
# 7218
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/CurrentMapInstanceMessage.as
# 563 567
# 9701
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/DiceRollRequestMessage.as
# 616 620
# 2939
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapComplementaryInformationsWithCoordsMessage.as
# 1196 1200
# 4600
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapRunningFightDetailsExtendedMessage.as
# 777 781
# 3023
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapInformationsRequestMessage.as
# 623 627
# 6532
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/GameRolePlayShowActorWithEventMessage.as
# 685 689
# 9756
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapFightStartPositionsUpdateMessage.as
# 718 722
# 2289
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/GameRolePlayShowMultipleActorsMessage.as
# 791 795
# 6327
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapComplementaryInformationsDataInHouseMessage.as
# 1279 1283
# 8788
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapRunningFightListMessage.as
# 712 716
# 1693
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapRunningFightDetailsRequestMessage.as
# 630 634
# 5911
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/AnomalySubareaInformationRequestMessage.as
# 633 637
# 5479
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/ErrorMapNotFoundMessage.as
# 617 621
# 6569
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapRunningFightDetailsMessage.as
# 784 788
# 4377
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/AnomalySubareaInformationResponseMessage.as
# 729 733
# 6858
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/ChangeMapMessage.as
# 610 614
# 4712
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapComplementaryInformationsDataMessage.as
# 1285 1289
# 6062
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/MapRunningFightListRequestMessage.as
# 627 631
# 6402
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/anomaly/MapComplementaryInformationsAnomalyMessage.as
# 1313 1317
# 9668
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/anomaly/AnomalyOpenedMessage.as
# 622 626
# 6804
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/anomaly/AnomalyStateMessage.as
# 621 625
# 7886
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/fight/GameRolePlayAggressionMessage.as
# 629 633
# 3917
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/fight/GameRolePlayMonsterAngryAtPlayerMessage.as
# 639 642
# 470
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/context/roleplay/fight/GameRolePlayPlayerFightFriendlyAnsweredMessage.as
# 646 650
# 1332
# ...
# 637 641
# 6438
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/CreateGuildRankRequestMessage.as
# 612 616
# 6742
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildGetChestTabContributionsRequestMessage.as
# 626 630
# 3036
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildInformationsGeneralMessage.as
# 614 618
# 5204
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildChestTabContributionsMessage.as
# 687 691
# 2687
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildKickRequestMessage.as
# 606 610
# 5916
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildPaddockBoughtMessage.as
# 695 699
# 5010
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildMotdSetErrorMessage.as
# 651 655
# 1589
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildCreationValidMessage.as
# 678 682
# 6479
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildMemberOnlineStatusMessage.as
# 613 617
# 5955
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildSelectChestTabRequestMessage.as
# 616 620
# 8333
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildInvitationSearchMessage.as
# 758 762
# 6288
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildModificationNameValidMessage.as
# 616 619
# 929
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildHouseRemoveMessage.as
# 606 610
# 4715
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildUpdateChestTabRequestMessage.as
# 707 711
# 8449
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildBulletinSetRequestMessage.as
# 661 665
# 1184
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildInformationsMemberUpdateMessage.as
# 689 693
# 8214
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildRanksMessage.as
# 679 683
# 2740
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildInAllianceFactsMessage.as
# 842 846
# 8611
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildSpellUpgradeRequestMessage.as
# 614 618
# 9315
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/StopListenGuildChestStructureMessage.as
# 619 623
# 1494
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildInvitationStateRecruterMessage.as
# 618 622
# 9160
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildInvitationMessage.as
# 605 609
# 2538
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildMemberLeavingMessage.as
# 608 612
# 7087
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildMotdSetRequestMessage.as
# 657 661
# 6060
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildCreationStartedMessage.as
# 610 614
# 9587
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildGetInformationsMessage.as
# 610 614
# 4881
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildMotdMessage.as
# 627 631
# 8900
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildChestTabContributionMessage.as
# 615 619
# 7980
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildModificationEmblemValidMessage.as
# 688 692
# 6730
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildVersatileInfoListMessage.as
# 759 763
# 2816
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildLevelUpMessage.as
# 602 606
# 4968
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildLeftMessage.as
# 599 603
# 8009
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildFactsErrorMessage.as
# 605 609
# 1805
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildModificationValidMessage.as
# 682 686
# 4016
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/GuildInvitationAnswerMessage.as
# 611 615
# 1590
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/logbook/GuildLogbookInformationMessage.as
# 782 786
# 4346
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/logbook/GuildLogbookInformationRequestMessage.as
# 628 632
# 5393
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/recruitment/RecruitmentInformationMessage.as
# 722 726
# 5770
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/recruitment/GuildRecruitmentInvalidateMessage.as
# 628 632
# 4402
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/recruitment/UpdateRecruitmentInformationMessage.as
# 728 732
# 2295
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorListMessage.as
# 749 753
# 3385
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorErrorMessage.as
# 611 615
# 5423
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GuildFightPlayersEnemiesListMessage.as
# 721 724
# 494
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GuildFightPlayersHelpersJoinMessage.as
# 721 725
# 9864
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorMovementRemoveMessage.as
# 620 623
# 557
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorMovementMessage.as
# 706 710
# 1685
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GuildFightJoinRequestMessage.as
# 615 619
# 6440
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TopTaxCollectorListMessage.as
# 658 662
# 1294
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GuildFightPlayersHelpersLeaveMessage.as
# 623 627
# 7948
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GameRolePlayTaxCollectorFightRequestMessage.as
# 630 634
# 4237
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorMovementAddMessage.as
# 765 769
# 6144
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorAttackedResultMessage.as
# 804 808
# 5179
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorStateUpdateMessage.as
# 617 621
# 9802
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GuildFightTakePlaceRequestMessage.as
# 575 578
# 617
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GuildFightPlayersEnemyRemoveMessage.as
# 622 626
# 8467
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorAttackedMessage.as
# 706 710
# 5024
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/GuildFightLeaveRequestMessage.as
# 616 620
# 7648
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/TaxCollectorMovementsOfflineMessage.as
# 705 709
# 3305
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/tax/AbstractTaxCollectorListMessage.as
# 766 770
# 5765
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/chest/RemoveListenerOnSynchronizedStorageMessage.as
# 631 635
# 5289
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/chest/ListenersOfSynchronizedStorageMessage.as
# 626 630
# 9734
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/chest/AddListenerOnSynchronizedStorageMessage.as
# 628 632
# 9135
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildDeleteApplicationRequestMessage.as
# 631 635
# 4677
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildPlayerApplicationAbstractMessage.as
# 632 636
# 9960
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildGetPlayerApplicationMessage.as
# 627 631
# 9033
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildListApplicationAnswerMessage.as
# 771 775
# 6506
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildApplicationAnswerMessage.as
# 624 628
# 3448
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildListApplicationModifiedMessage.as
# 728 732
# 2323
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildPlayerNoApplicationInformationMessage.as
# 601 605
# 7912
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildUpdateNoteMessage.as
# 617 620
# 486
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildSubmitApplicationMessage.as
# 624 628
# 4117
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildPlayerApplicationInformationMessage.as
# 784 788
# 6006
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildApplicationIsAnsweredMessage.as
# 715 719
# 3628
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildListApplicationRequestMessage.as
# 676 680
# 3750
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildUpdateApplicationMessage.as
# 624 628
# 1194
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildApplicationListenMessage.as
# 624 627
# 596
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildApplicationReceivedMessage.as
# 626 630
# 2640
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/game/guild/application/GuildApplicationDeletedMessage.as
# 625 628
# 930
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/subscription/AccountInformationsUpdateMessage.as
# 617 621
# 6161
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/common/NetworkDataContainerMessage.as
# 709 710
# 2
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/common/basic/BasicStatWithDataMessage.as
# 687 691
# 2395
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/common/basic/BasicPongMessage.as
# 601 604
# 693
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/common/basic/BasicStatMessage.as
# 601 605
# 8831
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/common/basic/BasicPingMessage.as
# 601 604
# 107
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/secure/TrustStatusMessage.as
# 666 669
# 321
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/queues/QueueStatusMessage.as
# 597 601
# 3862
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/queues/LoginQueueStatusMessage.as
# 602 606
# 3868
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/wtf/ClientYouAreDrunkMessage.as
# 624 628
# 9688
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/debug/DebugClearHighlightCellsMessage.as
# 609 613
# 4162
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/debug/DebugInClientMessage.as
# 598 602
# 5683
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/debug/DumpedEntityStatsMessage.as
# 704 708
# 9228
# /Users/thomasaudevie/Desktop/projets-perso/kamarketplace/sources/scripts/com/ankamagames/dofus/network/messages/debug/DebugHighlightCellsMessage.as
# 604 608
# 8113
# Terminé 1145

# %%
loadIds()

# %% [markdown]
# # Deserialize
